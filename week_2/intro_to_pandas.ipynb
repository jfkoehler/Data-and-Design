# %% [markdown]
# ### Introduction to Pandas

# %%
import pandas as pd

# %%
#make a dataframe from a dictionary
artists = {'drake': ['hotline', 's2', 's3'],
          'six nine': ['goobi', 's2', 's3'],
          'john legend': ['all of me', 's2', 's3']}

# %%
df = pd.DataFrame(artists)

# %%
df
# Out:
#      drake six nine john legend
# 0  hotline    goobi   all of me
# 1       s2       s2          s2
# 2       s3       s3          s3

# %%
#link to datasets on nyc open data
data_url = 'https://data.cityofnewyork.us/resource/qgea-i56i.json'

# %%
crime = pd.read_json(data_url)

# %%
crime.head(2)
# Out:
#    cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm             cmplnt_to_dt  \
# 0   724718389  2014-09-04T00:00:00.000     17:25:00  2014-09-04T00:00:00.000
# 1   191133903  2016-10-12T00:00:00.000     07:40:00  2016-10-12T00:00:00.000
#
#   cmplnt_to_tm  addr_pct_cd                   rpt_dt  ky_cd  \
# 0     17:35:00           81  2014-09-04T00:00:00.000    344
# 1     07:45:00          121  2016-10-12T00:00:00.000    109
#
#                       ofns_desc  pd_cd  ... :@computed_region_yeji_bk3q  \
# 0  ASSAULT 3 & RELATED OFFENSES  101.0  ...                         2.0
# 1                 GRAND LARCENY  417.0  ...                         1.0
#
#   :@computed_region_92fq_4b7q :@computed_region_sbqj_enih susp_age_group  \
# 0                        17.0                        52.0            NaN
# 1                        13.0                        75.0        UNKNOWN
#
#   susp_race susp_sex parks_nm  transit_district station_name  hadevelopt
# ...

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cmplnt_num                   1000 non-null   int64
#  1   cmplnt_fr_dt                 1000 non-null   object
#  2   cmplnt_fr_tm                 1000 non-null   object
#  3   cmplnt_to_dt                 787 non-null    object
#  4   cmplnt_to_tm                 788 non-null    object
#  5   addr_pct_cd                  1000 non-null   int64
#  6   rpt_dt                       1000 non-null   object
#  7   ky_cd                        1000 non-null   int64
#  8   ofns_desc                    999 non-null    object
#  9   pd_cd                        997 non-null    float64
#  10  pd_desc                      997 non-null    object
#  11  crm_atpt_cptd_cd             1000 non-null   object
#  12  law_cat_cd                   1000 non-null   object
# ...

# %%
#select a column
crime['susp_race']
# Out:
# 0                 NaN
# 1               BLACK
# 2      WHITE HISPANIC
# 3               BLACK
# 4      WHITE HISPANIC
#             ...
# 995               NaN
# 996    WHITE HISPANIC
# 997             BLACK
# 998           UNKNOWN
# 999             BLACK
# Name: susp_race, Length: 1000, dtype: object

# %%
#count the number of occurences in column
crime['susp_race'].value_counts()
# Out:
# BLACK                             208
# UNKNOWN                           130
# WHITE HISPANIC                    101
# WHITE                              57
# BLACK HISPANIC                     36
# ASIAN / PACIFIC ISLANDER           24
# AMERICAN INDIAN/ALASKAN NATIVE      3
# Name: susp_race, dtype: int64

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cmplnt_num                   1000 non-null   int64
#  1   cmplnt_fr_dt                 1000 non-null   object
#  2   cmplnt_fr_tm                 1000 non-null   object
#  3   cmplnt_to_dt                 787 non-null    object
#  4   cmplnt_to_tm                 788 non-null    object
#  5   addr_pct_cd                  1000 non-null   int64
#  6   rpt_dt                       1000 non-null   object
#  7   ky_cd                        1000 non-null   int64
#  8   ofns_desc                    999 non-null    object
#  9   pd_cd                        997 non-null    float64
#  10  pd_desc                      997 non-null    object
#  11  crm_atpt_cptd_cd             1000 non-null   object
#  12  law_cat_cd                   1000 non-null   object
# ...

# %%
crime['transit_district'].mean()
# Out:
# 13.25

# %%
col_names = ['vic_age_group', 'vic_race', 'vic_sex']
age_race_sex = crime[col_names]

# %%
type(age_race_sex)
# Out:
# pandas.core.frame.DataFrame

# %%
age_race_sex.head(2)
# Out:
#   vic_age_group        vic_race vic_sex
# 0         25-44           WHITE       F
# 1         45-64  WHITE HISPANIC       F

# %%
crime[['transit_district']].mean()
# Out:
# transit_district    13.25
# dtype: float64

# %%
crime.transit_district
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 995   NaN
# 996   NaN
# 997   NaN
# 998   NaN
# 999   NaN
# Name: transit_district, Length: 1000, dtype: float64

# %%
crime.head(3)
# Out:
#    cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm             cmplnt_to_dt  \
# 0   724718389  2014-09-04T00:00:00.000     17:25:00  2014-09-04T00:00:00.000
# 1   191133903  2016-10-12T00:00:00.000     07:40:00  2016-10-12T00:00:00.000
# 2   720151206  2012-09-28T00:00:00.000     13:30:00  2012-09-28T00:00:00.000
#
#   cmplnt_to_tm  addr_pct_cd                   rpt_dt  ky_cd  \
# 0     17:35:00           81  2014-09-04T00:00:00.000    344
# 1     07:45:00          121  2016-10-12T00:00:00.000    109
# 2     14:00:00           41  2012-10-19T00:00:00.000    109
#
#                       ofns_desc  pd_cd  ... :@computed_region_yeji_bk3q  \
# 0  ASSAULT 3 & RELATED OFFENSES  101.0  ...                         2.0
# 1                 GRAND LARCENY  417.0  ...                         1.0
# 2                 GRAND LARCENY  413.0  ...                         5.0
#
#   :@computed_region_92fq_4b7q :@computed_region_sbqj_enih susp_age_group  \
# ...

# %%
age_race_sex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   vic_age_group  791 non-null    object
#  1   vic_race       1000 non-null   object
#  2   vic_sex        1000 non-null   object
# dtypes: object(3)
# memory usage: 23.6+ KB

# %%
age_race_sex.describe()
# Out:
#        vic_age_group vic_race vic_sex
# count            791     1000    1000
# unique             6        7       4
# top            25-44  UNKNOWN       F
# freq             333      338     389

# %%
#crime.to_csv('sample_nyc_crime.csv')

# %%
#reading in data

#high level overview of data -- .info(), .describe()

#selecting columns -- df['colname'], df[['col1', 'col2']]

#doing things to these columns -- col.mean(), col.value_counts()

# %%
#select the row numbered 1
crime.iloc[1]
# Out:
# cmplnt_num                                                             191133903
# cmplnt_fr_dt                                             2016-10-12T00:00:00.000
# cmplnt_fr_tm                                                            07:40:00
# cmplnt_to_dt                                             2016-10-12T00:00:00.000
# cmplnt_to_tm                                                            07:45:00
# addr_pct_cd                                                                  121
# rpt_dt                                                   2016-10-12T00:00:00.000
# ky_cd                                                                        109
# ofns_desc                                                          GRAND LARCENY
# pd_cd                                                                        417
# pd_desc                                           LARCENY,GRAND FROM PERSON,PURS
# crm_atpt_cptd_cd                                                       COMPLETED
# ...

# %%
crime.head(2)
# Out:
#    cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm             cmplnt_to_dt  \
# 0   724718389  2014-09-04T00:00:00.000     17:25:00  2014-09-04T00:00:00.000
# 1   191133903  2016-10-12T00:00:00.000     07:40:00  2016-10-12T00:00:00.000
#
#   cmplnt_to_tm  addr_pct_cd                   rpt_dt  ky_cd  \
# 0     17:35:00           81  2014-09-04T00:00:00.000    344
# 1     07:45:00          121  2016-10-12T00:00:00.000    109
#
#                       ofns_desc  pd_cd  ... :@computed_region_yeji_bk3q  \
# 0  ASSAULT 3 & RELATED OFFENSES  101.0  ...                         2.0
# 1                 GRAND LARCENY  417.0  ...                         1.0
#
#   :@computed_region_92fq_4b7q :@computed_region_sbqj_enih susp_age_group  \
# 0                        17.0                        52.0            NaN
# 1                        13.0                        75.0        UNKNOWN
#
#   susp_race susp_sex parks_nm  transit_district station_name  hadevelopt
# ...

# %%
#select row, columns
crime.loc[1, ['latitude', 'longitude']]
# Out:
# latitude      40.637
# longitude   -74.1341
# Name: 1, dtype: object

# %%
crime.iloc[1, [4, 5]]
# Out:
# cmplnt_to_tm    07:45:00
# addr_pct_cd          121
# Name: 1, dtype: object

# %%
3 > 5
# Out:
# False

# %%
'tim' == 'steve'
# Out:
# False

# %%
a = 'steve'

# %%
crime['ofns_desc'].value_counts()
# Out:
# PETIT LARCENY                      168
# HARRASSMENT 2                      120
# ASSAULT 3 & RELATED OFFENSES       109
# GRAND LARCENY                      104
# CRIMINAL MISCHIEF & RELATED OF     100
# DANGEROUS DRUGS                     52
# FELONY ASSAULT                      45
# OFF. AGNST PUB ORD SENSBLTY &       38
# BURGLARY                            37
# ROBBERY                             37
# INTOXICATED & IMPAIRED DRIVING      25
# DANGEROUS WEAPONS                   23
# OFFENSES AGAINST PUBLIC ADMINI      18
# MISCELLANEOUS PENAL LAW             18
# CRIMINAL TRESPASS                   15
# SEX CRIMES                          14
# VEHICLE AND TRAFFIC LAWS            12
# THEFT-FRAUD                         12
# GRAND LARCENY OF MOTOR VEHICLE      12
# FRAUDS                               6
# UNAUTHORIZED USE OF A VEHICLE        5
# RAPE                                 4
# FORGERY                              4
# OFFENSES INVOLVING FRAUD             3
# ...

# %%
#select the columns
larceny = crime.loc[crime['ofns_desc'] == 'GRAND LARCENY']

# %%
crime.loc[(crime['ofns_desc'] == 'GRAND LARCENY')
          |(crime['ofns_desc'] == 'ARSON') |
            (crime['latitude'] > 20)]
# Out:
#      cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm  \
# 0     724718389  2014-09-04T00:00:00.000     17:25:00
# 1     191133903  2016-10-12T00:00:00.000     07:40:00
# 2     720151206  2012-09-28T00:00:00.000     13:30:00
# 3     232242098  2015-03-24T00:00:00.000     15:45:00
# 4     708078702  2017-05-20T00:00:00.000     04:02:00
# ..          ...                      ...          ...
# 994   679112387  2013-08-20T00:00:00.000     08:30:00
# 996   925856922  2016-01-19T00:00:00.000     16:15:00
# 997   594728309  2012-10-04T00:00:00.000     16:15:00
# 998   636703123  2016-10-18T00:00:00.000     14:00:00
# 999   581256959  2013-08-01T00:00:00.000     09:00:00
#
#                 cmplnt_to_dt cmplnt_to_tm  addr_pct_cd  \
# 0    2014-09-04T00:00:00.000     17:35:00           81
# 1    2016-10-12T00:00:00.000     07:45:00          121
# 2    2012-09-28T00:00:00.000     14:00:00           41
# 3                        NaN          NaN           46
# ...
