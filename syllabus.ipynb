# %% [markdown]
# # Data  and Design
#
#
#
# **INSTRUCTOR**: Jacob Frias Koehler, PhD
#
# **LOCATION**: 600 East 16th St
#
# **TIME**: Monday 12:10 - 2:50 pm
#
# **WEBSITE**: https://github.com/jfkoehler/data-and-design
#
#
#
# This course is an introduction to the Python computing language through an exploration of contemporary uses of data and computing technology.  We will combine work on understanding the political developments with the human use of data and engage with actual implementation of code and data analysis.
#
# ## Course Requirements
#
# - participate in class discussions on readings and computing work (20 %)
#
# - contribute to slack each week (5 %)
#
# - complete weekly assignments  (60%)
#
# - complete final project (15%)
#
#
#
# -----
#
# ### Resources
#
#
#
#
# The university provides many resources to help students achieve academic and artistic excellence.  These resources include:
#
# - The University (and associated) Libraries: http://library.newschool.edu
# - The University Learning Center: http://www.newschool.edu/learning-center
# - University Disabilities Service: www.newschool.edu/student-disability-services/
#
# In keeping with the university’s policy of providing equal access for students with disabilities, any student with a disability who needs academic accommodations is welcome to meet with me privately. All conversations will be kept confidential. Students requesting any accommodations will also need to contact Student Disability Service (SDS). SDS will conduct an intake and, if appropriate, the Director will provide an academic accommodation notification letter for you to bring to me. At that point, I will review the letter with you and discuss these accommodations in relation to this course.

# %% [markdown]
# ### Schedule
#
# - Week 1: Introduction to Python
#  - Activity: Data Types, Collections, Control Flow
#  - Assignment: Code Problems
#
#
# - Week 2: Introduction to Pandas
#  - Activity: EDA With Police Data
#  - Assignment: Chipotle and IMDB Data
#
#
# - Week 3: Plotting and  Visualization
#  - Activity: Matplotlib and Seaborn
#  - Activity: Bokeh
#  - Assignment:  Plotting with Matplotlib
#
#
# - Week 4: Data Project
#  - Activity: Mapping
#  - Assignment: Project Completion
#
#
# - Week 5: HTML and CSS
#  - Activity: Basic Website
#  - Assignment: Website Completion
#
#
# - Week 6: Flask
#  - Activity: Templates
#  - Activity: Arguments
#  - Assignment: Page Layouts
#
#
# - Week 7: Flask Forms and Email
#  - Activity: API
#  - Activity: Forms
#  - Assignment: Designing your Application
#
#
# - Week 8: Visualizations with D3.js
#  - Activity: Bar Chart
#  - Activity: API Visualization
#  - Assignment: Flask Visualizations
#
#
# - Week 9: Machine Learning I
#  - Activity:  Regression
#  - Activity: Classification
#  - Assignment: Regression and Classification
#
#
# - Week 10: Machine Learning II
#  - Activity: ANN's and Classification
#  - Activity: ANN's and Regression
#  - Assignment: Regression and Classification II
#
#
# - Week 11: Natural Language Processing
#  - Activity: Sklearn and Text
#  - Activity: Keras and Text
#  - Assignment: Final Project
